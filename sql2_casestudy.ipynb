# %% [markdown]
# <a href="https://colab.research.google.com/github/Aravindh-sreeni/assignment-case-study/blob/main/sql2_casestudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install requests

# %%
import pandas as pd
import requests

# %% [markdown]
# #Step 1: Load SpaceX Launch Data from API

# %%
launch_url = 'https://api.spacexdata.com/v4/launches'
launch_response = requests.get(launch_url)
launch_response
# Out:
# <Response [200]>

# %%
launch_data = launch_response.json()
df_launch = pd.DataFrame(launch_data)
launches=df_launch[['name','date_utc','success','details','rocket']]
launches
# Out:
#                        name                  date_utc success  \
# 0                 FalconSat  2006-03-24T22:30:00.000Z   False
# 1                   DemoSat  2007-03-21T01:10:00.000Z   False
# 2               Trailblazer  2008-08-03T03:34:00.000Z   False
# 3                    RatSat  2008-09-28T23:15:00.000Z    True
# 4                  RazakSat  2009-07-13T03:35:00.000Z    True
# ..                      ...                       ...     ...
# 200           Transporter-6  2022-12-01T00:00:00.000Z    None
# 201                   TTL-1  2022-12-01T00:00:00.000Z    None
# 202  WorldView Legion 1 & 2  2022-12-01T00:00:00.000Z    None
# 203     Viasat-3 & Arcturus  2022-12-01T00:00:00.000Z    None
# 204          O3b mPower 3.4  2022-12-01T00:00:00.000Z    None
#
#                                                details  \
# 0     Engine failure at 33 seconds and loss of vehicle
# 1    Successful first stage burn and transition to ...
# ...

# %%
launches['date_utc'] = pd.to_datetime(launches['date_utc'])
launches['year'] = launches['date_utc'].dt.year
launches
# Out:
# /tmp/ipython-input-34-2656700631.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   launches['date_utc'] = pd.to_datetime(launches['date_utc'])
# /tmp/ipython-input-34-2656700631.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   launches['year'] = launches['date_utc'].dt.year
#                        name                  date_utc success  \
# 0                 FalconSat 2006-03-24 22:30:00+00:00   False
# 1                   DemoSat 2007-03-21 01:10:00+00:00   False
# ...

# %% [markdown]
# # Step 2: Load Rocket Metadata

# %%
rocket_url = 'https://api.spacexdata.com/v4/rockets'
rocket_response = requests.get(rocket_url)
rocket_response
# Out:
# <Response [200]>

# %%
rocket_data = rocket_response.json()
df_rocket = pd.DataFrame(rocket_data)
rockets = df_rocket[['id','name','type','active','stages']]
rockets
# Out:
#                          id          name    type  active  stages
# 0  5e9d0d95eda69955f709d1eb      Falcon 1  rocket   False       2
# 1  5e9d0d95eda69973a809d1ec      Falcon 9  rocket    True       2
# 2  5e9d0d95eda69974db09d1ed  Falcon Heavy  rocket    True       2
# 3  5e9d0d96eda699382d09d1ee      Starship  rocket   False       2

# %% [markdown]
# #Step 3: Merge Launch and Rocket Data

# %%
merger_df = pd.merge(launches,rockets, left_on='rocket', right_on='id')
merger_df = merger_df.drop(['rocket'],axis = 1)

merger_df
# Out:
#                      name_x                  date_utc success  \
# 0                 FalconSat 2006-03-24 22:30:00+00:00   False
# 1                   DemoSat 2007-03-21 01:10:00+00:00   False
# 2               Trailblazer 2008-08-03 03:34:00+00:00   False
# 3                    RatSat 2008-09-28 23:15:00+00:00    True
# 4                  RazakSat 2009-07-13 03:35:00+00:00    True
# ..                      ...                       ...     ...
# 200           Transporter-6 2022-12-01 00:00:00+00:00    None
# 201                   TTL-1 2022-12-01 00:00:00+00:00    None
# 202  WorldView Legion 1 & 2 2022-12-01 00:00:00+00:00    None
# 203     Viasat-3 & Arcturus 2022-12-01 00:00:00+00:00    None
# 204          O3b mPower 3.4 2022-12-01 00:00:00+00:00    None
#
#                                                details  year  \
# 0     Engine failure at 33 seconds and loss of vehicle  2006
# 1    Successful first stage burn and transition to ...  2007
# ...

# %% [markdown]
# #Step 4: Add Simulated Country Information

# %%
import random

# %%
countries=['USA','Russia','India','China','France']
merger_df['country'] = [random.choice(countries) for i in range(len(merger_df))]
merger_df
# Out:
#                      name_x                  date_utc success  \
# 0                 FalconSat 2006-03-24 22:30:00+00:00   False
# 1                   DemoSat 2007-03-21 01:10:00+00:00   False
# 2               Trailblazer 2008-08-03 03:34:00+00:00   False
# 3                    RatSat 2008-09-28 23:15:00+00:00    True
# 4                  RazakSat 2009-07-13 03:35:00+00:00    True
# ..                      ...                       ...     ...
# 200           Transporter-6 2022-12-01 00:00:00+00:00    None
# 201                   TTL-1 2022-12-01 00:00:00+00:00    None
# 202  WorldView Legion 1 & 2 2022-12-01 00:00:00+00:00    None
# 203     Viasat-3 & Arcturus 2022-12-01 00:00:00+00:00    None
# 204          O3b mPower 3.4 2022-12-01 00:00:00+00:00    None
#
#                                                details  year  \
# 0     Engine failure at 33 seconds and loss of vehicle  2006
# 1    Successful first stage burn and transition to ...  2007
# ...

# %% [markdown]
# #Step 5: Store Merged Data in SQLite3

# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('launches.db')
merger_df.to_sql('launches', conn, if_exists='replace', index=False)
# Out:
# 205

# %% [markdown]
# #Step 6: Run SQL Queries on the Data to analyze

# %%
launches_by_country = pd.read_sql_query('SELECT country, COUNT(*) as count FROM launches GROUP BY country', conn)
launches_by_country
# Out:
#   country  count
# 0   China     39
# 1  France     41
# 2   India     35
# 3  Russia     43
# 4     USA     47

# %%
year_high_no_of_launches = pd.read_sql_query('SELECT year, COUNT(*) as count FROM launches GROUP BY year ORDER BY count DESC LIMIT 1', conn)
year_high_no_of_launches
# Out:
#    year  count
# 0  2022     62

# %%
top_5_missions_by_launch_count = pd.read_sql_query('SELECT name_x, COUNT(*) as count FROM launches GROUP BY name_x ORDER BY count DESC LIMIT 5', conn)
top_5_missions_by_launch_count
# Out:
#                       name_x  count
# 0  ispace Mission 1 & Rashid      1
# 1                       ZUMA      1
# 2     WorldView Legion 1 & 2      1
# 3        Viasat-3 & Arcturus      1
# 4                    USSF-44      1
